# %%
url = 'https://api.devhub.virginia.edu/v1/courses'

# %%
import json
import urllib
import requests
import pprint
import pandas as pd

# %%
data = requests.get(url)
final = json.loads(data.text)
columns = final['class_schedules']['columns']
records = final['class_schedules']['records']

# %%
subject = []
catalog_number = []
class_section = []
professor = []
term = []
year = []

# creates a list of integers that give each entry a unique record number 

record_number = list(range(len(records)))

for record in records:
    # gives shortened subject title  
    subject.append(record[0])
    
    # gives course number 
    catalog_number.append(record[1])
    
    # gives setion number if multiple sections
    class_section.append(record[2])
    
    # formats professor name 
    name = record[6].replace("'", "").split(",")
    if len(name) > 1:
        correclty_ordered_name = name[1] + name[0]
    else:
        correclty_ordered_name = ''
    professor.append(correclty_ordered_name)
    
    #gives fall/summer/spring 
    term.append(record[12].split()[1])
    
    # gives year of the specific class 
    year.append(record[12].split()[0])

   
# combines previous values to give one input for classCode 
finalCourseCode = []
letters = pd.Series(data=subject)
numbers = pd.Series(data=catalog_number)
sect = pd.Series(data=class_section)

for i in range(len(letters)):
    final = letters[i] + numbers[i] + class_section[i]
    finalCourseCode.append(final)
    
# when this is printed, the output can be copied into an insert statement to populate the class table in sql 
for i in range(len(finalCourseCode)):
    if finalCourseCode[i][:2] == "CS":
        print("(" + str(record_number[i]) + ", '" + finalCourseCode[i] + "', '" + term[i] +"', " + year[i] + ", '" + professor[i] +"'),")
# Out:
# (2031, 'CS1010001', 'Fall', 2022, ''),
# (2032, 'CS1110001', 'Fall', 2022, 'Raymond SPettit'),
# (2033, 'CS1110002', 'Fall', 2022, 'Briana B.Morrison'),
# (2034, 'CS1110003', 'Fall', 2022, 'Raymond SPettit'),
# (2035, 'CS1110004', 'Fall', 2022, 'Briana B.Morrison'),
# (2036, 'CS1110101', 'Fall', 2022, 'Raymond SPettit'),
# (2037, 'CS1110102', 'Fall', 2022, 'Raymond SPettit'),
# (2038, 'CS1110103', 'Fall', 2022, 'Raymond SPettit'),
# (2039, 'CS1110104', 'Fall', 2022, 'Raymond SPettit'),
# (2040, 'CS1110105', 'Fall', 2022, 'Raymond SPettit'),
# (2041, 'CS1110106', 'Fall', 2022, 'Raymond SPettit'),
# (2042, 'CS1110107', 'Fall', 2022, 'Raymond SPettit'),
# (2043, 'CS1110108', 'Fall', 2022, 'Raymond SPettit'),
# (2044, 'CS1110109', 'Fall', 2022, 'Raymond SPettit'),
# (2045, 'CS1110501', 'Fall', 2022, 'Victoria Van Luit'),
# (2046, 'CS1111001', 'Fall', 2022, 'Panagiotis Apostolellis'),
# (2047, 'CS1112001', 'Fall', 2022, 'James PCohoon'),
# (2048, 'CS1501001', 'Fall', 2022, 'Geoffrey C.Fox'),
# (2049, 'CS2100001', 'Fall', 2022, 'Thomas BHorton'),
# (2050, 'CS2100002', 'Fall', 2022, 'Derrick JavadStone'),
# (2051, 'CS2100003', 'Fall', 2022, 'NadaBasit'),
# (2052, 'CS2100004', 'Fall', 2022, ''),
# (2053, 'CS2100101', 'Fall', 2022, 'NadaBasit'),
# (2054, 'CS2100102', 'Fall', 2022, 'NadaBasit'),
# (2055, 'CS2100103', 'Fall', 2022, 'NadaBasit'),
# (2056, 'CS2100104', 'Fall', 2022, 'NadaBasit'),
# (2057, 'CS2100105', 'Fall', 2022, 'NadaBasit'),
# (2058, 'CS2100106', 'Fall', 2022, 'NadaBasit'),
# (2059, 'CS2100501', 'Fall', 2022, 'Elizabeth A.Wellbeloved'),
# (2060, 'CS2120001', 'Fall', 2022, 'Elizabeth MaeOrrico'),
# (2061, 'CS2120002', 'Fall', 2022, 'Kevin JSullivan'),
# (2062, 'CS2120003', 'Fall', 2022, 'Elizabeth MaeOrrico'),
# (2063, 'CS2120004', 'Fall', 2022, 'Nathan JamesBrunelle'),
# (2064, 'CS2120501', 'Fall', 2022, 'Elizabeth A.Wellbeloved'),
# (2065, 'CS2130001', 'Fall', 2022, 'John RobertHott'),
# (2066, 'CS2130002', 'Fall', 2022, 'John RobertHott'),
# (2067, 'CS2130101', 'Fall', 2022, ''),
# (2068, 'CS2130102', 'Fall', 2022, ''),
# (2069, 'CS2130103', 'Fall', 2022, ''),
# (2070, 'CS2130104', 'Fall', 2022, ''),
# (2071, 'CS2130105', 'Fall', 2022, ''),
# (2072, 'CS2130106', 'Fall', 2022, ''),
# (2073, 'CS2130501', 'Fall', 2022, 'Elizabeth A.Wellbeloved'),
# (2074, 'CS2150001', 'Fall', 2022, 'Aaron SBloomfield'),
# (2075, 'CS2150101', 'Fall', 2022, 'Aaron SBloomfield'),
# (2076, 'CS2910001', 'Fall', 2022, 'NadaBasit'),
# (2077, 'CS3100001', 'Fall', 2022, 'Mark RichardFloryan'),
# (2078, 'CS3100002', 'Fall', 2022, 'Mark RichardFloryan'),
# (2079, 'CS3102001', 'Fall', 2022, 'Nathan JamesBrunelle'),
# (2080, 'CS3130001', 'Fall', 2022, 'Luther A.Tychonievich'),
# (2081, 'CS3130101', 'Fall', 2022, 'Luther A.Tychonievich'),
# (2082, 'CS3130102', 'Fall', 2022, 'Luther A.Tychonievich'),
# (2083, 'CS3140001', 'Fall', 2022, 'Paul WilliamMcBurney'),
# (2084, 'CS3140002', 'Fall', 2022, 'Nhat HNguyen'),
# (2085, 'CS3205001', 'Fall', 2022, 'Panagiotis Apostolellis'),
# (2086, 'CS3240001', 'Fall', 2022, 'Paul WilliamMcBurney'),
# (2087, 'CS3240002', 'Fall', 2022, 'Mark SSherriff'),
# (2088, 'CS3240101', 'Fall', 2022, 'Mark SSherriff'),
# (2089, 'CS3250001', 'Fall', 2022, 'Upsorn Praphamontripong'),
# (2090, 'CS3330001', 'Fall', 2022, 'Charles Reiss'),
# (2091, 'CS3330002', 'Fall', 2022, 'Charles Reiss'),
# (2092, 'CS3330101', 'Fall', 2022, 'Charles Reiss'),
# (2093, 'CS3330102', 'Fall', 2022, 'Charles Reiss'),
# (2094, 'CS3330103', 'Fall', 2022, 'Charles Reiss'),
# (2095, 'CS3330104', 'Fall', 2022, 'Charles Reiss'),
# (2096, 'CS3330105', 'Fall', 2022, 'Charles Reiss'),
# (2097, 'CS3330106', 'Fall', 2022, 'Charles Reiss'),
# (2098, 'CS3330107', 'Fall', 2022, 'Charles Reiss'),
# (2099, 'CS3330108', 'Fall', 2022, 'Charles Reiss'),
# (2100, 'CS3330501', 'Fall', 2022, 'Victoria Van Luit'),
# (2101, 'CS3710001', 'Fall', 2022, 'Angela DOrebaugh'),
# (2102, 'CS3710002', 'Fall', 2022, 'William StuartShand'),
# (2103, 'CS4414001', 'Fall', 2022, 'KevinSkadron'),
# (2104, 'CS4414501', 'Fall', 2022, 'Victoria Van Luit'),
# (2105, 'CS4501001', 'Fall', 2022, 'Yixin  Sun'),
# (2106, 'CS4501002', 'Fall', 2022, 'David EEvans'),
# (2107, 'CS4501003', 'Fall', 2022, 'Angela DOrebaugh'),
# (2108, 'CS4501004', 'Fall', 2022, 'Aaron SBloomfield'),
# (2109, 'CS4501005', 'Fall', 2022, 'Sebastian Elbaum'),
# (2110, 'CS4501006', 'Fall', 2022, 'Tianhao Wang'),
# (2111, 'CS4501007', 'Fall', 2022, 'Miaomiao Zhang'),
# (2112, 'CS4501008', 'Fall', 2022, 'Hongning Wang'),
# (2113, 'CS4501009', 'Fall', 2022, 'Farzad FHassanzadeh'),
# (2114, 'CS4620001', 'Fall', 2022, 'Matthew BDwyer'),
# (2115, 'CS4630001', 'Fall', 2022, 'Wajih Ul Hassan'),
# (2116, 'CS4710001', 'Fall', 2022, 'Lu Feng'),
# (2117, 'CS4720001', 'Fall', 2022, 'Mark SSherriff'),
# (2118, 'CS4740001', 'Fall', 2022, 'Neal EMagee'),
# (2119, 'CS4750001', 'Fall', 2022, 'Upsorn Praphamontripong'),
# (2120, 'CS4750002', 'Fall', 2022, ''),
# (2121, 'CS4750501', 'Fall', 2022, 'Victoria Van Luit'),
# (2122, 'CS4774001', 'Fall', 2022, 'Nhat HNguyen'),
# (2123, 'CS4980001', 'Fall', 2022, 'David J.Wu'),
# (2124, 'CS4980002', 'Fall', 2022, 'Haifeng Xu'),
# (2125, 'CS4980003', 'Fall', 2022, 'Seongkook Heo'),
# (2126, 'CS4980004', 'Fall', 2022, 'Daniel GeorgeGraham'),
# (2127, 'CS4980005', 'Fall', 2022, 'Jack WDavidson'),
# (2128, 'CS4980006', 'Fall', 2022, 'Mary LouSoffa'),
# (2129, 'CS4980007', 'Fall', 2022, 'Aidong Zhang'),
# (2130, 'CS4980008', 'Fall', 2022, 'Alfred CWeaver'),
# (2131, 'CS4980009', 'Fall', 2022, 'Yonghwi Kwon'),
# (2132, 'CS4980010', 'Fall', 2022, 'Nhat HNguyen'),
# (2133, 'CS4980011', 'Fall', 2022, 'David EEvans'),
# (2134, 'CS4980012', 'Fall', 2022, 'Madhav VMarathe'),
# (2135, 'CS4980013', 'Fall', 2022, 'James PCohoon'),
# (2136, 'CS4980014', 'Fall', 2022, 'Rosanne FaeVrugtman'),
# (2137, 'CS4980015', 'Fall', 2022, 'James PCohoon'),
# (2138, 'CS4980016', 'Fall', 2022, 'James PCohoon'),
# (2139, 'CS4980017', 'Fall', 2022, 'Aaron SBloomfield'),
# (2140, 'CS4980018', 'Fall', 2022, 'Yuan Tian'),
# (2141, 'CS4980019', 'Fall', 2022, 'Sebastian Elbaum'),
# (2142, 'CS4980020', 'Fall', 2022, 'Madhur Behl'),
# (2143, 'CS4980021', 'Fall', 2022, 'Mark SSherriff'),
# (2144, 'CS4980022', 'Fall', 2022, 'Mark RichardFloryan'),
# (2145, 'CS4980023', 'Fall', 2022, 'Yanjun Qi'),
# (2146, 'CS4980024', 'Fall', 2022, 'John RobertHott'),
# (2147, 'CS4980025', 'Fall', 2022, 'James PCohoon'),
# (2148, 'CS4980026', 'Fall', 2022, 'NadaBasit'),
# (2149, 'CS4980027', 'Fall', 2022, 'Ashish Venkat'),
# (2150, 'CS4980028', 'Fall', 2022, 'Nicola Bezzo'),
# (2151, 'CS4980029', 'Fall', 2022, 'Kristen MNaegle'),
# (2152, 'CS4980030', 'Fall', 2022, 'Luther A.Tychonievich'),
# (2153, 'CS4980031', 'Fall', 2022, 'Hongning Wang'),
# (2154, 'CS4980032', 'Fall', 2022, 'Haiying Shen'),
# (2155, 'CS4980033', 'Fall', 2022, 'Denis Nekipelov'),
# (2156, 'CS4980034', 'Fall', 2022, 'Charles Reiss'),
# (2157, 'CS4980035', 'Fall', 2022, 'Ahmed Ibrahim'),
# (2158, 'CS4980036', 'Fall', 2022, 'Upsorn Praphamontripong'),
# (2159, 'CS4980037', 'Fall', 2022, 'Baishakhi Ray'),
# (2160, 'CS4980038', 'Fall', 2022, 'Lu Feng'),
# (2161, 'CS4980039', 'Fall', 2022, 'Thomas Pinckney'),
# (2162, 'CS4980040', 'Fall', 2022, 'Nathan JamesBrunelle'),
# (2163, 'CS4980041', 'Fall', 2022, 'Tariq Iqbal'),
# (2164, 'CS4980042', 'Fall', 2022, 'Homa Alemzadeh'),
# (2165, 'CS4980043', 'Fall', 2022, 'Jonathan LeeGoodall'),
# (2166, 'CS4980044', 'Fall', 2022, 'Afsaneh Doryab'),
# (2167, 'CS4980045', 'Fall', 2022, 'Paul WilliamMcBurney'),
# (2168, 'CS4980046', 'Fall', 2022, 'YangfengJi'),
# (2169, 'CS4980047', 'Fall', 2022, 'Farzad FHassanzadeh'),
# (2170, 'CS4980048', 'Fall', 2022, 'Xiaozhu Lin'),
# (2171, 'CS4980049', 'Fall', 2022, 'Raymond SPettit'),
# (2172, 'CS4980050', 'Fall', 2022, 'Elizabeth MaeOrrico'),
# (2173, 'CS4980051', 'Fall', 2022, 'Yixin  Sun'),
# (2174, 'CS4991001', 'Fall', 2022, 'Rosanne FaeVrugtman'),
# (2175, 'CS4991002', 'Fall', 2022, 'Rosanne FaeVrugtman'),
# (2176, 'CS4993001', 'Fall', 2022, 'Aaron SBloomfield'),
# (2177, 'CS4993002', 'Fall', 2022, 'Mark SSherriff'),
# (2178, 'CS4993003', 'Fall', 2022, 'Thomas BHorton'),
# (2179, 'CS4993004', 'Fall', 2022, 'Aidong Zhang'),
# (2180, 'CS4993005', 'Fall', 2022, 'Anil Kumar SrinivasaVullikanti'),
# (2181, 'CS4993006', 'Fall', 2022, 'Madhav VMarathe'),
# (2182, 'CS4993007', 'Fall', 2022, 'Nicola Bezzo'),
# (2183, 'CS4993008', 'Fall', 2022, 'Luther A.Tychonievich'),
# (2184, 'CS4993009', 'Fall', 2022, 'David EEvans'),
# (2185, 'CS4993010', 'Fall', 2022, 'John RobertHott'),
# (2186, 'CS4993011', 'Fall', 2022, 'Panagiotis Apostolellis'),
# (2187, 'CS4993012', 'Fall', 2022, 'David J.Wu'),
# (2188, 'CS4993013', 'Fall', 2022, 'Haifeng Xu'),
# (2189, 'CS4993014', 'Fall', 2022, 'Seongkook Heo'),
# (2190, 'CS4993015', 'Fall', 2022, 'Ashish Venkat'),
# (2191, 'CS4993016', 'Fall', 2022, 'Daniel GeorgeGraham'),
# (2192, 'CS4993017', 'Fall', 2022, 'Jack WDavidson'),
# (2193, 'CS4993018', 'Fall', 2022, 'Yanjun Qi'),
# (2194, 'CS4993019', 'Fall', 2022, 'Homa Alemzadeh'),
# (2195, 'CS4993020', 'Fall', 2022, 'Madhur Behl'),
# (2196, 'CS4993021', 'Fall', 2022, 'Bradford Campbell'),
# (2197, 'CS4993022', 'Fall', 2022, 'Mark RichardFloryan'),
# (2198, 'CS4993023', 'Fall', 2022, 'Yonghwi Kwon'),
# (2199, 'CS4993024', 'Fall', 2022, 'NadaBasit'),
# (2200, 'CS4993025', 'Fall', 2022, 'Hongning Wang'),
# (2201, 'CS4993026', 'Fall', 2022, 'Kristen MNaegle'),
# (2202, 'CS4993027', 'Fall', 2022, 'Denis Nekipelov'),
# (2203, 'CS4993028', 'Fall', 2022, 'Tariq Iqbal'),
# (2204, 'CS4993029', 'Fall', 2022, 'Afsaneh Doryab'),
# (2205, 'CS4993030', 'Fall', 2022, 'Upsorn Praphamontripong'),
# (2206, 'CS4993031', 'Fall', 2022, 'Yixin  Sun'),
# (2207, 'CS4993032', 'Fall', 2022, 'Samira ManabiKhan'),
# (2208, 'CS4993033', 'Fall', 2022, 'Judy Fox'),
# (2209, 'CS4993034', 'Fall', 2022, 'Haiying Shen'),
# (2210, 'CS4993035', 'Fall', 2022, 'YangfengJi'),
# (2211, 'CS4993036', 'Fall', 2022, 'Jundong Li'),
# (2212, 'CS4993037', 'Fall', 2022, 'Ahmed Ibrahim'),
# (2213, 'CS4993038', 'Fall', 2022, 'James PCohoon'),
# (2214, 'CS4993039', 'Fall', 2022, 'Lu Feng'),
# (2215, 'CS4993040', 'Fall', 2022, 'Nathan JamesBrunelle'),
# (2216, 'CS4993041', 'Fall', 2022, 'Geoffrey C.Fox'),
# (2217, 'CS4993042', 'Fall', 2022, 'Yuan Tian'),
# (2218, 'CS4993043', 'Fall', 2022, 'Elizabeth MaeOrrico'),
# (2219, 'CS4993045', 'Fall', 2022, 'Jonathan LeeGoodall'),
# (2220, 'CS4993050', 'Fall', 2022, 'Sebastian Elbaum'),
# (2221, 'CS4998001', 'Fall', 2022, 'David EEvans'),
# (2222, 'CS4998002', 'Fall', 2022, 'Yuan Tian'),
# (2223, 'CS4998003', 'Fall', 2022, 'Panagiotis Apostolellis'),
# (2224, 'CS4998004', 'Fall', 2022, 'Hongning Wang'),
# (2225, 'CS4998005', 'Fall', 2022, 'John RobertHott'),
# (2226, 'CS4998006', 'Fall', 2022, 'Daniel GeorgeGraham'),
# (2227, 'CS4998007', 'Fall', 2022, 'David J.Wu'),
# (2228, 'CS4998008', 'Fall', 2022, 'Haifeng Xu'),
# (2229, 'CS4998009', 'Fall', 2022, 'Seongkook Heo'),
# (2230, 'CS4998010', 'Fall', 2022, 'Sebastian Elbaum'),
# (2231, 'CS4998011', 'Fall', 2022, 'Ashish Venkat'),
# (2232, 'CS4998012', 'Fall', 2022, 'Homa Alemzadeh'),
# (2233, 'CS4998013', 'Fall', 2022, 'Yanjun Qi'),
# (2234, 'CS4998014', 'Fall', 2022, 'Mark SSherriff'),
# (2235, 'CS4998015', 'Fall', 2022, 'Madhav VMarathe'),
# (2236, 'CS4998016', 'Fall', 2022, 'Ku-Lung Hsu'),
# (2237, 'CS4998017', 'Fall', 2022, 'Edmond CraigDukes'),
# (2238, 'CS4998018', 'Fall', 2022, 'Mona Kasra'),
# (2239, 'CS4998019', 'Fall', 2022, 'Tariq Iqbal'),
# (2240, 'CS4998020', 'Fall', 2022, 'Gizem Korkmaz'),
# (2241, 'CS4998021', 'Fall', 2022, 'OlivierPfister'),
# (2242, 'CS4998022', 'Fall', 2022, 'Nicola Bezzo'),
# (2243, 'CS4998023', 'Fall', 2022, 'Kristen MNaegle'),
# (2244, 'CS4998024', 'Fall', 2022, 'Denis Nekipelov'),
# (2245, 'CS4998025', 'Fall', 2022, 'Afsaneh Doryab'),
# (2246, 'CS4998026', 'Fall', 2022, 'Judy Fox'),
# (2247, 'CS4998027', 'Fall', 2022, 'Michele PaigeClaibourn'),
# (2248, 'CS4998028', 'Fall', 2022, 'Nhat HNguyen'),
# (2249, 'CS4998029', 'Fall', 2022, 'Panagiotis Apostolellis'),
# (2250, 'CS5012001', 'Fall', 2022, 'Rafael CandidoAlvarado'),
# (2251, 'CS5012002', 'Fall', 2022, 'Adam PaulTashman'),
# (2252, 'CS6111001', 'Fall', 2022, 'Haiying Shen'),
# (2253, 'CS6161001', 'Fall', 2022, 'Haifeng Xu'),
# (2254, 'CS6190001', 'Fall', 2022, ''),
# (2255, 'CS6316001', 'Fall', 2022, 'Aidong Zhang'),
# (2256, 'CS6354001', 'Fall', 2022, 'Ashish Venkat'),
# (2257, 'CS6501001', 'Fall', 2022, 'Seongkook Heo'),
# (2258, 'CS6501002', 'Fall', 2022, 'Preston ThomasFletcher IV'),
# (2259, 'CS6501003', 'Fall', 2022, 'Arsalan Heydarian'),
# (2260, 'CS6501004', 'Fall', 2022, 'Afsaneh Doryab'),
# (2261, 'CS6501005', 'Fall', 2022, 'Madhur Behl'),
# (2262, 'CS6501006', 'Fall', 2022, ''),
# (2263, 'CS6501007', 'Fall', 2022, ''),
# (2264, 'CS6501008', 'Fall', 2022, 'Farzad FHassanzadeh'),
# (2265, 'CS6501010', 'Fall', 2022, 'Miaomiao Zhang'),
# (2266, 'CS6501012', 'Fall', 2022, 'Nicola Bezzo'),
# (2267, 'CS6501013', 'Fall', 2022, 'Bradford Campbell'),
# (2268, 'CS6501014', 'Fall', 2022, ''),
# (2269, 'CS6501015', 'Fall', 2022, ''),
# (2270, 'CS6762001', 'Fall', 2022, 'Xiaozhu Lin'),
# (2271, 'CS6890001', 'Fall', 2022, 'Yuan Tian'),
# (2272, 'CS6890002', 'Fall', 2022, 'Farzad FHassanzadeh'),
# (2273, 'CS6890003', 'Fall', 2022, 'Madhav VMarathe'),
# (2274, 'CS6890004', 'Fall', 2022, 'David EEvans'),
# (2275, 'CS6890005', 'Fall', 2022, 'David J.Wu'),
# (2276, 'CS6890006', 'Fall', 2022, 'Miaomiao Zhang'),
# (2277, 'CS6890007', 'Fall', 2022, 'Quanquan Gu'),
# (2278, 'CS6890008', 'Fall', 2022, 'Aidong Zhang'),
# (2279, 'CS6890009', 'Fall', 2022, 'Haifeng Xu'),
# (2280, 'CS6890010', 'Fall', 2022, 'Seongkook Heo'),
# (2281, 'CS6890011', 'Fall', 2022, 'Sebastian Elbaum'),
# (2282, 'CS6890012', 'Fall', 2022, 'Cameron DeanWhitehouse'),
# (2283, 'CS6890013', 'Fall', 2022, 'Ashish Venkat'),
# (2284, 'CS6890014', 'Fall', 2022, 'Baishakhi Ray'),
# (2285, 'CS6890015', 'Fall', 2022, 'Jack WDavidson'),
# (2286, 'CS6890016', 'Fall', 2022, 'Haiying Shen'),
# (2287, 'CS6890017', 'Fall', 2022, 'KevinSkadron'),
# (2288, 'CS6890018', 'Fall', 2022, 'Homa Alemzadeh'),
# (2289, 'CS6890019', 'Fall', 2022, 'John AStankovic'),
# (2290, 'CS6890020', 'Fall', 2022, 'Kevin JSullivan'),
# (2291, 'CS6890021', 'Fall', 2022, 'Hongning Wang'),
# (2292, 'CS6890022', 'Fall', 2022, 'Alfred CWeaver'),
# (2293, 'CS6890023', 'Fall', 2022, 'James PCohoon'),
# (2294, 'CS6890024', 'Fall', 2022, 'Lu Feng'),
# (2295, 'CS6890025', 'Fall', 2022, 'MohammadMahmoody'),
# (2296, 'CS6890026', 'Fall', 2022, 'Yanjun Qi'),
# (2297, 'CS6890027', 'Fall', 2022, 'Madhur Behl'),
# (2298, 'CS6890028', 'Fall', 2022, 'Charles Reiss'),
# (2299, 'CS6890029', 'Fall', 2022, 'Michael JAlbert'),
# (2300, 'CS6890030', 'Fall', 2022, 'Panagiotis Apostolellis'),
# (2301, 'CS6890031', 'Fall', 2022, 'NadaBasit'),
# (2302, 'CS6890032', 'Fall', 2022, 'Aaron SBloomfield'),
# (2303, 'CS6890033', 'Fall', 2022, 'Nathan JamesBrunelle'),
# (2304, 'CS6890034', 'Fall', 2022, 'Bradford Campbell'),
# (2305, 'CS6890035', 'Fall', 2022, 'Anil Kumar SrinivasaVullikanti'),
# (2306, 'CS6890036', 'Fall', 2022, 'Matthew BDwyer'),
# (2307, 'CS6890037', 'Fall', 2022, 'Preston ThomasFletcher IV'),
# (2308, 'CS6890038', 'Fall', 2022, 'Mark RichardFloryan'),
# (2309, 'CS6890039', 'Fall', 2022, 'Daniel GeorgeGraham'),
# (2310, 'CS6890040', 'Fall', 2022, 'Thomas BHorton'),
# (2311, 'CS6890041', 'Fall', 2022, 'John RobertHott'),
# (2312, 'CS6890042', 'Fall', 2022, 'Ahmed Ibrahim'),
# (2313, 'CS6890043', 'Fall', 2022, 'YangfengJi'),
# (2314, 'CS6890044', 'Fall', 2022, 'Samira ManabiKhan'),
# (2315, 'CS6890045', 'Fall', 2022, 'Yonghwi Kwon'),
# (2316, 'CS6890046', 'Fall', 2022, 'Jundong Li'),
# (2317, 'CS6890047', 'Fall', 2022, 'Worthy NMartin'),
# (2318, 'CS6890048', 'Fall', 2022, 'Paul WilliamMcBurney'),
# (2319, 'CS6890049', 'Fall', 2022, 'Nhat HNguyen'),
# (2320, 'CS6890050', 'Fall', 2022, 'Raymond SPettit'),
# (2321, 'CS6890051', 'Fall', 2022, 'Thomas Pinckney'),
# (2322, 'CS6890052', 'Fall', 2022, 'Upsorn Praphamontripong'),
# (2323, 'CS6890053', 'Fall', 2022, 'GabrielRobins'),
# (2324, 'CS6890054', 'Fall', 2022, 'Mark SSherriff'),
# (2325, 'CS6890055', 'Fall', 2022, 'Mary LouSoffa'),
# (2326, 'CS6890056', 'Fall', 2022, 'Derrick JavadStone'),
# (2327, 'CS6890057', 'Fall', 2022, 'Yixin  Sun'),
# (2328, 'CS6890058', 'Fall', 2022, 'Luther A.Tychonievich'),
# (2329, 'CS6890059', 'Fall', 2022, 'Xiaozhu Lin'),
# (2330, 'CS6993001', 'Fall', 2022, 'Homa Alemzadeh'),
# (2331, 'CS7993001', 'Fall', 2022, 'Aidong Zhang'),
# (2332, 'CS7993002', 'Fall', 2022, 'Anil Kumar SrinivasaVullikanti'),
# (2333, 'CS7993003', 'Fall', 2022, 'KevinSkadron'),
# (2334, 'CS7993004', 'Fall', 2022, 'Jack WDavidson'),
# (2335, 'CS7993005', 'Fall', 2022, 'NadaBasit'),
# (2336, 'CS7993006', 'Fall', 2022, 'Madhav VMarathe'),
# (2337, 'CS7993007', 'Fall', 2022, 'John RobertHott'),
# (2338, 'CS7993008', 'Fall', 2022, 'Lu Feng'),
# (2339, 'CS7993009', 'Fall', 2022, 'Upsorn Praphamontripong'),
# (2340, 'CS7993010', 'Fall', 2022, 'David J.Wu'),
# (2341, 'CS7993011', 'Fall', 2022, 'Haifeng Xu'),
# (2342, 'CS7993012', 'Fall', 2022, 'Samira ManabiKhan'),
# (2343, 'CS7993013', 'Fall', 2022, 'Seongkook Heo'),
# (2344, 'CS7993014', 'Fall', 2022, 'Sebastian Elbaum'),
# (2345, 'CS7993015', 'Fall', 2022, 'Ashish Venkat'),
# (2346, 'CS7993016', 'Fall', 2022, 'Homa Alemzadeh'),
# (2347, 'CS7993017', 'Fall', 2022, 'Bradford Campbell'),
# (2348, 'CS7993018', 'Fall', 2022, 'Jundong Li'),
# (2349, 'CS7993019', 'Fall', 2022, 'Afsaneh Doryab'),
# (2350, 'CS7993020', 'Fall', 2022, 'Madhur Behl'),
# (2351, 'CS7993021', 'Fall', 2022, 'Judy Fox'),
# (2352, 'CS7993022', 'Fall', 2022, 'Hongning Wang'),
# (2353, 'CS7993023', 'Fall', 2022, 'Yanjun Qi'),
# (2354, 'CS7993024', 'Fall', 2022, 'Haiying Shen'),
# (2355, 'CS7993025', 'Fall', 2022, 'Yuan Tian'),
# (2356, 'CS7993026', 'Fall', 2022, 'YangfengJi'),
# (2357, 'CS7993027', 'Fall', 2022, 'Yonghwi Kwon'),
# (2358, 'CS7993028', 'Fall', 2022, 'Xiaozhu Lin'),
# (2359, 'CS7993029', 'Fall', 2022, 'Kristen MNaegle'),
# (2360, 'CS7995001', 'Fall', 2022, 'David J.Wu'),
# (2361, 'CS7995002', 'Fall', 2022, 'David EEvans'),
# (2362, 'CS7995003', 'Fall', 2022, 'Anil Kumar SrinivasaVullikanti'),
# (2363, 'CS7995004', 'Fall', 2022, 'Madhav VMarathe'),
# (2364, 'CS7995005', 'Fall', 2022, 'Haifeng Xu'),
# (2365, 'CS7995006', 'Fall', 2022, 'Seongkook Heo'),
# (2366, 'CS7995007', 'Fall', 2022, 'Sebastian Elbaum'),
# (2367, 'CS7995008', 'Fall', 2022, 'Ashish Venkat'),
# (2368, 'CS7995009', 'Fall', 2022, 'NadaBasit'),
# (2369, 'CS7995010', 'Fall', 2022, 'Aidong Zhang'),
# (2370, 'CS7995011', 'Fall', 2022, 'Baishakhi Ray'),
# (2371, 'CS7995012', 'Fall', 2022, 'Homa Alemzadeh'),
# (2372, 'CS7995013', 'Fall', 2022, 'John AStankovic'),
# (2373, 'CS7995014', 'Fall', 2022, 'Nicola Bezzo'),
# (2374, 'CS7995015', 'Fall', 2022, 'Afsaneh Doryab'),
# (2375, 'CS7995016', 'Fall', 2022, 'Hongning Wang'),
# (2376, 'CS7995017', 'Fall', 2022, 'Mark SSherriff'),
# (2377, 'CS7995018', 'Fall', 2022, 'MohammadMahmoody'),
# (2378, 'CS7995019', 'Fall', 2022, 'Madhur Behl'),
# (2379, 'CS7995020', 'Fall', 2022, 'Yuan Tian'),
# (2380, 'CS8501001', 'Fall', 2022, 'YangfengJi'),
# (2381, 'CS8897001', 'Fall', 2022, 'Jack WDavidson'),
# (2382, 'CS8897002', 'Fall', 2022, 'David EEvans'),
# (2383, 'CS8897003', 'Fall', 2022, 'James PCohoon'),
# (2384, 'CS8897004', 'Fall', 2022, 'Connelly SBarnes'),
# (2385, 'CS8897005', 'Fall', 2022, 'Homa Alemzadeh'),
# (2386, 'CS8897006', 'Fall', 2022, 'KevinSkadron'),
# (2387, 'CS8897007', 'Fall', 2022, 'Aidong Zhang'),
# (2388, 'CS8897008', 'Fall', 2022, 'Yixin  Sun'),
# (2389, 'CS8897009', 'Fall', 2022, 'Baishakhi Ray'),
# (2390, 'CS8897010', 'Fall', 2022, 'Aaron SBloomfield'),
# (2391, 'CS8897011', 'Fall', 2022, 'Neal EMagee'),
# (2392, 'CS8897012', 'Fall', 2022, 'Kai-Wei Chang'),
# (2393, 'CS8897013', 'Fall', 2022, 'Thomas BHorton'),
# (2394, 'CS8897014', 'Fall', 2022, 'Samira ManabiKhan'),
# (2395, 'CS8897015', 'Fall', 2022, 'Bradford Campbell'),
# (2396, 'CS8897016', 'Fall', 2022, 'Worthy NMartin'),
# (2397, 'CS8897017', 'Fall', 2022, 'NadaBasit'),
# (2398, 'CS8897018', 'Fall', 2022, 'GabrielRobins'),
# (2399, 'CS8897019', 'Fall', 2022, 'Quanquan Gu'),
# (2400, 'CS8897020', 'Fall', 2022, 'MohammadMahmoody'),
# (2401, 'CS8897021', 'Fall', 2022, 'Kevin JSullivan'),
# (2402, 'CS8897022', 'Fall', 2022, 'Alfred CWeaver'),
# (2403, 'CS8897023', 'Fall', 2022, 'Madhur Behl'),
# (2404, 'CS8897024', 'Fall', 2022, 'Cameron DeanWhitehouse'),
# (2405, 'CS8897025', 'Fall', 2022, 'Mark SSherriff'),
# (2406, 'CS8897026', 'Fall', 2022, 'Craig Dill'),
# (2407, 'CS8897027', 'Fall', 2022, 'Kong-Cheng Wong'),
# (2408, 'CS8897028', 'Fall', 2022, 'David LinvilleEdwards'),
# (2409, 'CS8897029', 'Fall', 2022, 'Hongning Wang'),
# (2410, 'CS8897030', 'Fall', 2022, 'Mark RichardFloryan'),
# (2411, 'CS8897031', 'Fall', 2022, 'Luther A.Tychonievich'),
# (2412, 'CS8897032', 'Fall', 2022, 'Yanjun Qi'),
# (2413, 'CS8897033', 'Fall', 2022, 'Haiying Shen'),
# (2414, 'CS8897034', 'Fall', 2022, 'Preston ThomasFletcher IV'),
# (2415, 'CS8897035', 'Fall', 2022, 'Charles Reiss'),
# (2416, 'CS8897036', 'Fall', 2022, 'Ahmed Ibrahim'),
# (2417, 'CS8897037', 'Fall', 2022, 'Upsorn Praphamontripong'),
# (2418, 'CS8897038', 'Fall', 2022, 'Mary LaverneSmith'),
# (2419, 'CS8897039', 'Fall', 2022, 'Abdeltawab Hendawi'),
# (2420, 'CS8897040', 'Fall', 2022, 'DimitriosDiochnos'),
# (2421, 'CS8897041', 'Fall', 2022, 'Lu Feng'),
# (2422, 'CS8897042', 'Fall', 2022, 'Nathan JamesBrunelle'),
# (2423, 'CS8897043', 'Fall', 2022, 'Farzad FHassanzadeh'),
# (2424, 'CS8897044', 'Fall', 2022, 'Yuan Tian'),
# (2425, 'CS8897045', 'Fall', 2022, 'Matthew BDwyer'),
# (2426, 'CS8897046', 'Fall', 2022, 'Sebastian Elbaum'),
# (2427, 'CS8897047', 'Fall', 2022, 'YangfengJi'),
# (2428, 'CS8897048', 'Fall', 2022, 'Yonghwi Kwon'),
# (2429, 'CS8897049', 'Fall', 2022, 'Ashish Venkat'),
# (2430, 'CS8897050', 'Fall', 2022, 'Daniel GeorgeGraham'),
# (2431, 'CS8897051', 'Fall', 2022, 'John RobertHott'),
# (2432, 'CS8897052', 'Fall', 2022, 'Nhat HNguyen'),
# (2433, 'CS8897053', 'Fall', 2022, 'Raymond SPettit'),
# (2434, 'CS8897054', 'Fall', 2022, 'Afsaneh Doryab'),
# (2435, 'CS8999001', 'Fall', 2022, 'Cameron DeanWhitehouse'),
# (2436, 'CS8999002', 'Fall', 2022, 'James PCohoon'),
# (2437, 'CS8999003', 'Fall', 2022, 'Jack WDavidson'),
# (2438, 'CS8999004', 'Fall', 2022, 'David EEvans'),
# (2439, 'CS8999005', 'Fall', 2022, 'Connelly SBarnes'),
# (2440, 'CS8999006', 'Fall', 2022, 'Afsaneh Doryab'),
# (2441, 'CS8999007', 'Fall', 2022, 'Hongning Wang'),
# (2442, 'CS8999008', 'Fall', 2022, 'Yanjun Qi'),
# (2443, 'CS8999009', 'Fall', 2022, 'Thomas BHorton'),
# (2444, 'CS8999010', 'Fall', 2022, 'Yixin  Sun'),
# (2445, 'CS8999011', 'Fall', 2022, 'Mark SSherriff'),
# (2446, 'CS8999012', 'Fall', 2022, 'Bradford Campbell'),
# (2447, 'CS8999013', 'Fall', 2022, 'Baishakhi Ray'),
# (2448, 'CS8999014', 'Fall', 2022, 'Worthy NMartin'),
# (2449, 'CS8999015', 'Fall', 2022, 'MohammadMahmoody'),
# (2450, 'CS8999016', 'Fall', 2022, 'GabrielRobins'),
# (2451, 'CS8999017', 'Fall', 2022, 'Quanquan Gu'),
# (2452, 'CS8999018', 'Fall', 2022, 'KevinSkadron'),
# (2453, 'CS8999019', 'Fall', 2022, 'Judy Fox'),
# (2454, 'CS8999020', 'Fall', 2022, 'Miaomiao Zhang'),
# (2455, 'CS8999021', 'Fall', 2022, 'Xiaozhu Lin'),
# (2456, 'CS8999022', 'Fall', 2022, 'Kevin JSullivan'),
# (2457, 'CS8999023', 'Fall', 2022, 'Preston ThomasFletcher IV'),
# (2458, 'CS8999024', 'Fall', 2022, 'Madhur Behl'),
# (2459, 'CS8999025', 'Fall', 2022, 'Aaron SBloomfield'),
# (2460, 'CS8999026', 'Fall', 2022, 'Samira ManabiKhan'),
# (2461, 'CS8999027', 'Fall', 2022, 'Kai-Wei Chang'),
# (2462, 'CS8999028', 'Fall', 2022, 'Haiying Shen'),
# (2463, 'CS8999029', 'Fall', 2022, 'Nhat HNguyen'),
# (2464, 'CS8999030', 'Fall', 2022, 'Charles Reiss'),
# (2465, 'CS8999031', 'Fall', 2022, 'Ahmed Ibrahim'),
# (2466, 'CS8999032', 'Fall', 2022, 'Upsorn Praphamontripong'),
# (2467, 'CS8999033', 'Fall', 2022, 'Lu Feng'),
# (2468, 'CS8999034', 'Fall', 2022, 'Nathan JamesBrunelle'),
# (2469, 'CS8999035', 'Fall', 2022, 'Farzad FHassanzadeh'),
# (2470, 'CS8999036', 'Fall', 2022, 'Yuan Tian'),
# (2471, 'CS8999037', 'Fall', 2022, 'Homa Alemzadeh'),
# (2472, 'CS8999038', 'Fall', 2022, 'Jonathan LeeGoodall'),
# (2473, 'CS8999039', 'Fall', 2022, 'Denis Nekipelov'),
# (2474, 'CS8999040', 'Fall', 2022, 'Kristen MNaegle'),
# (2475, 'CS8999041', 'Fall', 2022, 'Matthew BDwyer'),
# (2476, 'CS8999042', 'Fall', 2022, 'Sebastian Elbaum'),
# (2477, 'CS8999043', 'Fall', 2022, 'YangfengJi'),
# (2478, 'CS8999044', 'Fall', 2022, 'Yonghwi Kwon'),
# (2479, 'CS8999045', 'Fall', 2022, 'Aidong Zhang'),
# (2480, 'CS8999046', 'Fall', 2022, 'Anil Kumar SrinivasaVullikanti'),
# (2481, 'CS8999047', 'Fall', 2022, 'Madhav VMarathe'),
# (2482, 'CS8999048', 'Fall', 2022, 'Michael JAlbert'),
# (2483, 'CS8999049', 'Fall', 2022, 'David J.Wu'),
# (2484, 'CS8999050', 'Fall', 2022, 'Haifeng Xu'),
# (2485, 'CS8999051', 'Fall', 2022, 'Seongkook Heo'),
# (2486, 'CS8999052', 'Fall', 2022, 'Ashish Venkat'),
# (2487, 'CS8999053', 'Fall', 2022, 'Jundong Li'),
# (2488, 'CS8999054', 'Fall', 2022, 'Nicola Bezzo'),
# (2489, 'CS9897001', 'Fall', 2022, 'Aaron SBloomfield'),
# (2490, 'CS9897002', 'Fall', 2022, 'Connelly SBarnes'),
# (2491, 'CS9897003', 'Fall', 2022, 'James PCohoon'),
# (2492, 'CS9897004', 'Fall', 2022, 'Jack WDavidson'),
# (2493, 'CS9897005', 'Fall', 2022, 'David EEvans'),
# (2494, 'CS9897007', 'Fall', 2022, 'David LinvilleEdwards'),
# (2495, 'CS9897008', 'Fall', 2022, 'Thomas BHorton'),
# (2496, 'CS9897010', 'Fall', 2022, 'Bradford Campbell'),
# (2497, 'CS9897011', 'Fall', 2022, 'Mark RichardFloryan'),
# (2498, 'CS9897012', 'Fall', 2022, 'Worthy NMartin'),
# (2499, 'CS9897013', 'Fall', 2022, 'Yanjun Qi'),
# (2500, 'CS9897014', 'Fall', 2022, 'Quanquan Gu'),
# (2501, 'CS9897015', 'Fall', 2022, 'Mark SSherriff'),
# (2502, 'CS9897016', 'Fall', 2022, 'KevinSkadron'),
# (2503, 'CS9897018', 'Fall', 2022, 'MohammadMahmoody'),
# (2504, 'CS9897020', 'Fall', 2022, 'Kevin JSullivan'),
# (2505, 'CS9897022', 'Fall', 2022, 'Madhur Behl'),
# (2506, 'CS9897024', 'Fall', 2022, 'Baishakhi Ray'),
# (2507, 'CS9897025', 'Fall', 2022, 'Samira ManabiKhan'),
# (2508, 'CS9897026', 'Fall', 2022, 'Kai-Wei Chang'),
# (2509, 'CS9897027', 'Fall', 2022, 'Haiying Shen'),
# (2510, 'CS9897029', 'Fall', 2022, 'Charles Reiss'),
# (2511, 'CS9897030', 'Fall', 2022, 'Ahmed Ibrahim'),
# (2512, 'CS9897031', 'Fall', 2022, 'Upsorn Praphamontripong'),
# (2513, 'CS9897032', 'Fall', 2022, 'Mary LaverneSmith'),
# (2514, 'CS9897033', 'Fall', 2022, 'Kong-Cheng Wong'),
# (2515, 'CS9897034', 'Fall', 2022, 'DimitriosDiochnos'),
# (2516, 'CS9897035', 'Fall', 2022, 'Lu Feng'),
# (2517, 'CS9897036', 'Fall', 2022, 'Nathan JamesBrunelle'),
# (2518, 'CS9897037', 'Fall', 2022, 'Farzad FHassanzadeh'),
# (2519, 'CS9897038', 'Fall', 2022, 'Yuan Tian'),
# (2520, 'CS9897039', 'Fall', 2022, 'Matthew BDwyer'),
# (2521, 'CS9897040', 'Fall', 2022, 'Sebastian Elbaum'),
# (2522, 'CS9897041', 'Fall', 2022, 'YangfengJi'),
# (2523, 'CS9897042', 'Fall', 2022, 'Yonghwi Kwon'),
# (2524, 'CS9897043', 'Fall', 2022, 'Ashish Venkat'),
# (2525, 'CS9897044', 'Fall', 2022, 'Daniel GeorgeGraham'),
# (2526, 'CS9897045', 'Fall', 2022, 'John RobertHott'),
# (2527, 'CS9897046', 'Fall', 2022, 'Nhat HNguyen'),
# (2528, 'CS9897047', 'Fall', 2022, 'Raymond SPettit'),
# (2529, 'CS9897048', 'Fall', 2022, 'Aidong Zhang'),
# (2530, 'CS9897049', 'Fall', 2022, 'David J.Wu'),
# (2531, 'CS9897050', 'Fall', 2022, 'Haifeng Xu'),
# (2532, 'CS9897051', 'Fall', 2022, 'Seongkook Heo'),
# (2533, 'CS9897052', 'Fall', 2022, 'Homa Alemzadeh'),
# (2534, 'CS9897053', 'Fall', 2022, 'Afsaneh Doryab'),
# (2535, 'CS9897054', 'Fall', 2022, 'Preston ThomasFletcher IV'),
# (2536, 'CS9897055', 'Fall', 2022, 'Neal EMagee'),
# (2537, 'CS9897056', 'Fall', 2022, 'Jeremy Bolton'),
# (2538, 'CS9999001', 'Fall', 2022, 'KevinSkadron'),
# (2539, 'CS9999002', 'Fall', 2022, 'James PCohoon'),
# (2540, 'CS9999003', 'Fall', 2022, 'Jack WDavidson'),
# (2541, 'CS9999004', 'Fall', 2022, 'Aaron SBloomfield'),
# (2542, 'CS9999005', 'Fall', 2022, 'Baishakhi Ray'),
# (2543, 'CS9999006', 'Fall', 2022, 'Preston ThomasFletcher IV'),
# (2544, 'CS9999007', 'Fall', 2022, 'Yixin  Sun'),
# (2545, 'CS9999008', 'Fall', 2022, 'David EEvans'),
# (2546, 'CS9999009', 'Fall', 2022, 'Connelly SBarnes'),
# (2547, 'CS9999010', 'Fall', 2022, 'Miaomiao Zhang'),
# (2548, 'CS9999011', 'Fall', 2022, 'Hongning Wang'),
# (2549, 'CS9999012', 'Fall', 2022, 'Yanjun Qi'),
# (2550, 'CS9999013', 'Fall', 2022, 'Jundong Li'),
# (2551, 'CS9999014', 'Fall', 2022, 'Samira ManabiKhan'),
# (2552, 'CS9999015', 'Fall', 2022, 'Bradford Campbell'),
# (2553, 'CS9999016', 'Fall', 2022, 'Worthy NMartin'),
# (2554, 'CS9999017', 'Fall', 2022, 'MohammadMahmoody'),
# (2555, 'CS9999018', 'Fall', 2022, 'GabrielRobins'),
# (2556, 'CS9999019', 'Fall', 2022, 'Madhur Behl'),
# (2557, 'CS9999020', 'Fall', 2022, 'Seongkook Heo'),
# (2558, 'CS9999021', 'Fall', 2022, 'Haifeng Xu'),
# (2559, 'CS9999022', 'Fall', 2022, 'Kai-Wei Chang'),
# (2560, 'CS9999023', 'Fall', 2022, 'Kevin JSullivan'),
# (2561, 'CS9999024', 'Fall', 2022, 'Quanquan Gu'),
# (2562, 'CS9999025', 'Fall', 2022, 'Thomas BHorton'),
# (2563, 'CS9999026', 'Fall', 2022, 'Haiying Shen'),
# (2564, 'CS9999027', 'Fall', 2022, 'Mark SSherriff'),
# (2565, 'CS9999028', 'Fall', 2022, 'David J.Wu'),
# (2566, 'CS9999029', 'Fall', 2022, 'Charles Reiss'),
# (2567, 'CS9999030', 'Fall', 2022, 'Ahmed Ibrahim'),
# (2568, 'CS9999031', 'Fall', 2022, 'Upsorn Praphamontripong'),
# (2569, 'CS9999032', 'Fall', 2022, 'Lu Feng'),
# (2570, 'CS9999033', 'Fall', 2022, 'Nathan JamesBrunelle'),
# (2571, 'CS9999034', 'Fall', 2022, 'Farzad FHassanzadeh'),
# (2572, 'CS9999035', 'Fall', 2022, 'Yuan Tian'),
# (2573, 'CS9999036', 'Fall', 2022, 'Matthew BDwyer'),
# (2574, 'CS9999037', 'Fall', 2022, 'Sebastian Elbaum'),
# (2575, 'CS9999038', 'Fall', 2022, 'YangfengJi'),
# (2576, 'CS9999039', 'Fall', 2022, 'Yonghwi Kwon'),
# (2577, 'CS9999040', 'Fall', 2022, 'Ashish Venkat'),
# (2578, 'CS9999041', 'Fall', 2022, 'Aidong Zhang'),
# (2579, 'CS9999042', 'Fall', 2022, 'Anil Kumar SrinivasaVullikanti'),
# (2580, 'CS9999043', 'Fall', 2022, 'Madhav VMarathe'),
# (2581, 'CS9999044', 'Fall', 2022, 'John AStankovic'),
# (11014, 'CS1110001', 'Spring', 2023, 'Raymond SPettit'),
# (11015, 'CS1110002', 'Spring', 2023, 'Raymond SPettit'),
# (11016, 'CS1110003', 'Spring', 2023, 'Aidan Weng-SheanSan'),
# (11017, 'CS1110100', 'Spring', 2023, 'Raymond SPettit'),
# (11018, 'CS1110101', 'Spring', 2023, 'Raymond SPettit'),
# (11019, 'CS1110102', 'Spring', 2023, 'Raymond SPettit'),
# (11020, 'CS1110103', 'Spring', 2023, 'Raymond SPettit'),
# (11021, 'CS1110104', 'Spring', 2023, 'Raymond SPettit'),
# (11022, 'CS1110105', 'Spring', 2023, 'Raymond SPettit'),
# (11023, 'CS1110106', 'Spring', 2023, 'Raymond SPettit'),
# (11024, 'CS1110107', 'Spring', 2023, 'Raymond SPettit'),
# (11025, 'CS1111001', 'Spring', 2023, 'Panagiotis Apostolellis'),
# (11026, 'CS1112001', 'Spring', 2023, 'Elizabeth MaeOrrico'),
# (11027, 'CS1501001', 'Spring', 2023, 'Haifeng Xu'),
# (11028, 'CS2100001', 'Spring', 2023, 'Mark RichardFloryan'),
# (11029, 'CS2100002', 'Spring', 2023, 'NadaBasit'),
# (11030, 'CS2100101', 'Spring', 2023, 'Mark RichardFloryan'),
# (11031, 'CS2100102', 'Spring', 2023, 'Mark RichardFloryan'),
# (11032, 'CS2100103', 'Spring', 2023, 'Mark RichardFloryan'),
# (11033, 'CS2100104', 'Spring', 2023, 'Mark RichardFloryan'),
# (11034, 'CS2110001', 'Spring', 2023, 'Derrick JavadStone'),
# (11035, 'CS2110101', 'Spring', 2023, 'Derrick JavadStone'),
# (11036, 'CS2120001', 'Spring', 2023, 'Elizabeth MaeOrrico'),
# (11037, 'CS2120002', 'Spring', 2023, 'Briana B.Morrison'),
# (11038, 'CS2120003', 'Spring', 2023, 'Briana B.Morrison'),
# (11039, 'CS2130001', 'Spring', 2023, 'Luther A.Tychonievich'),
# (11040, 'CS2130002', 'Spring', 2023, 'Daniel GeorgeGraham'),
# (11041, 'CS2130101', 'Spring', 2023, 'Luther A.Tychonievich'),
# (11042, 'CS2130102', 'Spring', 2023, 'Luther A.Tychonievich'),
# (11043, 'CS2150001', 'Spring', 2023, 'Aaron SBloomfield'),
# (11044, 'CS2150002', 'Spring', 2023, 'Mark RichardFloryan'),
# (11045, 'CS2150101', 'Spring', 2023, 'Aaron SBloomfield'),
# (11046, 'CS2150102', 'Spring', 2023, 'Aaron SBloomfield'),
# (11047, 'CS2150103', 'Spring', 2023, 'Aaron SBloomfield'),
# (11048, 'CS2150104', 'Spring', 2023, 'Aaron SBloomfield'),
# (11049, 'CS2150105', 'Spring', 2023, 'Aaron SBloomfield'),
# (11050, 'CS2150106', 'Spring', 2023, 'Aaron SBloomfield'),
# (11051, 'CS2150107', 'Spring', 2023, 'Aaron SBloomfield'),
# (11052, 'CS2910001', 'Spring', 2023, 'Nathan JamesBrunelle'),
# (11053, 'CS3102001', 'Spring', 2023, 'Nathan JamesBrunelle'),
# (11054, 'CS3205001', 'Spring', 2023, 'Panagiotis Apostolellis'),
# (11055, 'CS3240001', 'Spring', 2023, 'Paul WilliamMcBurney'),
# (11056, 'CS3240002', 'Spring', 2023, 'Paul WilliamMcBurney'),
# (11057, 'CS3240101', 'Spring', 2023, 'Paul WilliamMcBurney'),
# (11058, 'CS3250001', 'Spring', 2023, 'Upsorn Praphamontripong'),
# (11059, 'CS3330100', 'Spring', 2023, 'Ashish Venkat'),
# (11060, 'CS3330101', 'Spring', 2023, 'Ashish Venkat'),
# (11061, 'CS3330102', 'Spring', 2023, 'Ashish Venkat'),
# (11062, 'CS3330200', 'Spring', 2023, 'Luther A.Tychonievich'),
# (11063, 'CS3330201', 'Spring', 2023, 'Luther A.Tychonievich'),
# (11064, 'CS3330202', 'Spring', 2023, 'Luther A.Tychonievich'),
# (11065, 'CS3501001', 'Spring', 2023, 'Preston ThomasFletcher IV'),
# (11066, 'CS3501002', 'Spring', 2023, 'Joanne BDugan'),
# (11067, 'CS3501003', 'Spring', 2023, 'Jack WDavidson'),
# (11068, 'CS3710001', 'Spring', 2023, 'Angela DOrebaugh'),
# (11069, 'CS3710002', 'Spring', 2023, 'Angela DOrebaugh'),
# (11070, 'CS4102001', 'Spring', 2023, 'John RobertHott'),
# (11071, 'CS4102002', 'Spring', 2023, 'Thomas BHorton'),
# (11072, 'CS4414001', 'Spring', 2023, 'Charles Reiss'),
# (11073, 'CS4414002', 'Spring', 2023, 'Charles Reiss'),
# (11074, 'CS4434001', 'Spring', 2023, 'Homa Alemzadeh'),
# (11075, 'CS4457001', 'Spring', 2023, 'Bradford Campbell'),
# (11076, 'CS4501001', 'Spring', 2023, 'Haifeng Xu'),
# (11077, 'CS4501002', 'Spring', 2023, 'Jack WDavidson'),
# (11078, 'CS4501003', 'Spring', 2023, 'Madhur Behl'),
# (11079, 'CS4501004', 'Spring', 2023, 'Seongkook Heo'),
# (11080, 'CS4501006', 'Spring', 2023, 'John AStankovic'),
# (11081, 'CS4501007', 'Spring', 2023, 'YangfengJi'),
# (11082, 'CS4501009', 'Spring', 2023, 'David EEvans'),
# (11083, 'CS4501010', 'Spring', 2023, 'Aaron SBloomfield'),
# (11084, 'CS4640001', 'Spring', 2023, 'John RobertHott'),
# (11085, 'CS4740001', 'Spring', 2023, 'Haiying Shen'),
# (11086, 'CS4750001', 'Spring', 2023, 'Upsorn Praphamontripong'),
# (11087, 'CS4760001', 'Spring', 2023, 'Daniel GeorgeGraham'),
# (11088, 'CS4774001', 'Spring', 2023, 'Yanjun Qi'),
# (11089, 'CS4980001', 'Spring', 2023, 'Aaron SBloomfield'),
# (11090, 'CS4980002', 'Spring', 2023, 'James PCohoon'),
# (11091, 'CS4980003', 'Spring', 2023, 'Jack WDavidson'),
# (11092, 'CS4980004', 'Spring', 2023, 'David EEvans'),
# (11093, 'CS4980005', 'Spring', 2023, 'Mark RichardFloryan'),
# (11094, 'CS4980006', 'Spring', 2023, 'Homa Alemzadeh'),
# (11095, 'CS4980007', 'Spring', 2023, 'Hongning Wang'),
# (11096, 'CS4980008', 'Spring', 2023, 'Nicola Bezzo'),
# (11097, 'CS4980009', 'Spring', 2023, 'Kevin JSullivan'),
# (11098, 'CS4980010', 'Spring', 2023, 'Madhur Behl'),
# (11099, 'CS4980011', 'Spring', 2023, 'Jonathan LeeGoodall'),
# (11100, 'CS4980012', 'Spring', 2023, 'MohammadMahmoody'),
# (11101, 'CS4980013', 'Spring', 2023, 'Haiying Shen'),
# (11102, 'CS4980014', 'Spring', 2023, 'Yanjun Qi'),
# (11103, 'CS4980015', 'Spring', 2023, 'Kristen MNaegle'),
# (11104, 'CS4980016', 'Spring', 2023, 'Denis Nekipelov'),
# (11105, 'CS4980017', 'Spring', 2023, 'Mark SSherriff'),
# (11106, 'CS4980018', 'Spring', 2023, 'Daniel GeorgeGraham'),
# (11107, 'CS4980019', 'Spring', 2023, 'Sebastian Elbaum'),
# (11108, 'CS4980020', 'Spring', 2023, 'Samira ManabiKhan'),
# (11109, 'CS4980021', 'Spring', 2023, 'Jack WDavidson'),
# (11110, 'CS4980022', 'Spring', 2023, 'Alfred CWeaver'),
# (11111, 'CS4980023', 'Spring', 2023, 'Andrew SGrimshaw'),
# (11112, 'CS4980024', 'Spring', 2023, 'Luther A.Tychonievich'),
# (11113, 'CS4980025', 'Spring', 2023, 'Yonghwi Kwon'),
# (11114, 'CS4980026', 'Spring', 2023, 'NadaBasit'),
# (11115, 'CS4980027', 'Spring', 2023, 'Seongkook Heo'),
# (11116, 'CS4980028', 'Spring', 2023, 'Madhav VMarathe'),
# (11117, 'CS4980029', 'Spring', 2023, 'Nhat HNguyen'),
# (11118, 'CS4980030', 'Spring', 2023, 'KevinSkadron'),
# (11119, 'CS4980031', 'Spring', 2023, 'Worthy NMartin'),
# (11120, 'CS4980032', 'Spring', 2023, 'David J.Wu'),
# (11121, 'CS4980033', 'Spring', 2023, 'Matthew BDwyer'),
# (11122, 'CS4980034', 'Spring', 2023, 'Upsorn Praphamontripong'),
# (11123, 'CS4980035', 'Spring', 2023, 'YangfengJi'),
# (11124, 'CS4980036', 'Spring', 2023, 'Aidong Zhang'),
# (11125, 'CS4980037', 'Spring', 2023, 'Lu Feng'),
# (11126, 'CS4980038', 'Spring', 2023, 'Haifeng Xu'),
# (11127, 'CS4980039', 'Spring', 2023, 'Nathan JamesBrunelle'),
# (11128, 'CS4980040', 'Spring', 2023, 'James PCohoon'),
# (11129, 'CS4980041', 'Spring', 2023, 'Yuan Tian'),
# (11130, 'CS4980042', 'Spring', 2023, 'Paul WilliamMcBurney'),
# (11131, 'CS4980043', 'Spring', 2023, 'Bradford Campbell'),
# (11132, 'CS4980044', 'Spring', 2023, 'Elizabeth MaeOrrico'),
# (11133, 'CS4991001', 'Spring', 2023, 'Rosanne FaeVrugtman'),
# (11134, 'CS4991002', 'Spring', 2023, 'Rosanne FaeVrugtman'),
# (11135, 'CS4993001', 'Spring', 2023, 'Madhur Behl'),
# (11136, 'CS4993002', 'Spring', 2023, 'Ashish Venkat'),
# (11137, 'CS4993003', 'Spring', 2023, 'Andrew SGrimshaw'),
# (11138, 'CS4993004', 'Spring', 2023, 'Homa Alemzadeh'),
# (11139, 'CS4993005', 'Spring', 2023, 'Nicola Bezzo'),
# (11140, 'CS4993006', 'Spring', 2023, 'Jonathan LeeGoodall'),
# (11141, 'CS4993007', 'Spring', 2023, 'Denis Nekipelov'),
# (11142, 'CS4993008', 'Spring', 2023, 'Tariq Iqbal'),
# (11143, 'CS4993009', 'Spring', 2023, 'Anil Kumar SrinivasaVullikanti'),
# (11144, 'CS4993010', 'Spring', 2023, 'Mark SSherriff'),
# (11145, 'CS4993011', 'Spring', 2023, 'Kristen MNaegle'),
# (11146, 'CS4993012', 'Spring', 2023, 'Luther A.Tychonievich'),
# (11147, 'CS4993013', 'Spring', 2023, 'Alfred CWeaver'),
# (11148, 'CS4993014', 'Spring', 2023, 'John RobertHott'),
# (11149, 'CS4993015', 'Spring', 2023, 'Upsorn Praphamontripong'),
# (11150, 'CS4993016', 'Spring', 2023, 'Jack WDavidson'),
# (11151, 'CS4993017', 'Spring', 2023, 'Seongkook Heo'),
# (11152, 'CS4993018', 'Spring', 2023, 'Daniel GeorgeGraham'),
# (11153, 'CS4993019', 'Spring', 2023, 'Haiying Shen'),
# (11154, 'CS4993020', 'Spring', 2023, 'KevinSkadron'),
# (11155, 'CS4993021', 'Spring', 2023, 'NadaBasit'),
# (11156, 'CS4993022', 'Spring', 2023, 'Yanjun Qi'),
# (11157, 'CS4993023', 'Spring', 2023, 'Panagiotis Apostolellis'),
# (11158, 'CS4993024', 'Spring', 2023, 'YangfengJi'),
# (11159, 'CS4993025', 'Spring', 2023, 'David EEvans'),
# (11160, 'CS4993026', 'Spring', 2023, 'Hongning Wang'),
# (11161, 'CS4993027', 'Spring', 2023, 'Yonghwi Kwon'),
# (11162, 'CS4993028', 'Spring', 2023, 'David J.Wu'),
# (11163, 'CS4993029', 'Spring', 2023, 'Haifeng Xu'),
# (11164, 'CS4993030', 'Spring', 2023, 'Madhav VMarathe'),
# (11165, 'CS4993031', 'Spring', 2023, 'Nhat HNguyen'),
# (11166, 'CS4993032', 'Spring', 2023, 'Ahmed Ibrahim'),
# (11167, 'CS4993033', 'Spring', 2023, 'Mark RichardFloryan'),
# (11168, 'CS4993034', 'Spring', 2023, 'Yixin  Sun'),
# (11169, 'CS4993036', 'Spring', 2023, 'Vicente Ordonez-Roman'),
# (11170, 'CS4993037', 'Spring', 2023, 'Lu Feng'),
# (11171, 'CS4993038', 'Spring', 2023, 'Jundong Li'),
# (11172, 'CS4993039', 'Spring', 2023, 'Nathan JamesBrunelle'),
# (11173, 'CS4993040', 'Spring', 2023, 'Yuan Tian'),
# (11174, 'CS4993041', 'Spring', 2023, 'Afsaneh Doryab'),
# (11175, 'CS4993042', 'Spring', 2023, 'Mircea RStan'),
# (11176, 'CS4993043', 'Spring', 2023, 'Donald EBrown'),
# (11177, 'CS4993044', 'Spring', 2023, 'Farzad FHassanzadeh'),
# (11178, 'CS4993045', 'Spring', 2023, 'Thomas BHorton'),
# (11179, 'CS4993046', 'Spring', 2023, 'Elizabeth MaeOrrico'),
# (11180, 'CS4993600', 'Spring', 2023, 'Panagiotis Apostolellis'),
# (11181, 'CS4998001', 'Spring', 2023, 'Ashish Venkat'),
# (11182, 'CS4998002', 'Spring', 2023, 'Hongning Wang'),
# (11183, 'CS4998003', 'Spring', 2023, 'Yanjun Qi'),
# (11184, 'CS4998004', 'Spring', 2023, 'Mark SSherriff'),
# (11185, 'CS4998005', 'Spring', 2023, 'Homa Alemzadeh'),
# (11186, 'CS4998006', 'Spring', 2023, 'Nicola Bezzo'),
# (11187, 'CS4998007', 'Spring', 2023, 'Haifeng Xu'),
# (11188, 'CS4998008', 'Spring', 2023, 'Jonathan LeeGoodall'),
# (11189, 'CS4998009', 'Spring', 2023, 'Kristen MNaegle'),
# (11190, 'CS4998010', 'Spring', 2023, 'KevinSkadron'),
# (11191, 'CS4998011', 'Spring', 2023, 'David EEvans'),
# (11192, 'CS4998012', 'Spring', 2023, 'Panagiotis Apostolellis'),
# (11193, 'CS4998013', 'Spring', 2023, 'Yuan Tian'),
# (11194, 'CS4998014', 'Spring', 2023, 'Michele PaigeClaibourn'),
# (11195, 'CS4998015', 'Spring', 2023, 'Seongkook Heo'),
# (11196, 'CS4998016', 'Spring', 2023, 'Nhat HNguyen'),
# (11197, 'CS4998017', 'Spring', 2023, 'OlivierPfister'),
# (11198, 'CS4998018', 'Spring', 2023, 'Ku-Lung Hsu'),
# (11199, 'CS4998019', 'Spring', 2023, 'Mona Kasra'),
# (11200, 'CS4998020', 'Spring', 2023, 'Tariq Iqbal'),
# (11201, 'CS6161001', 'Spring', 2023, 'MohammadMahmoody'),
# (11202, 'CS6316001', 'Spring', 2023, 'YangfengJi'),
# (11203, 'CS6434001', 'Spring', 2023, 'Homa Alemzadeh'),
# (11204, 'CS6456001', 'Spring', 2023, 'Xiaozhu Lin'),
# (11205, 'CS6501001', 'Spring', 2023, 'Kevin JSullivan'),
# (11206, 'CS6501002', 'Spring', 2023, 'Yixin  Sun'),
# (11207, 'CS6501004', 'Spring', 2023, 'Yonghwi Kwon'),
# (11208, 'CS6501005', 'Spring', 2023, 'Seongkook Heo'),
# (11209, 'CS6501006', 'Spring', 2023, 'YangfengJi'),
# (11210, 'CS6501007', 'Spring', 2023, 'Nathan Sheffield'),
# (11211, 'CS6501008', 'Spring', 2023, 'Tianhao Wang'),
# (11212, 'CS6763001', 'Spring', 2023, 'Lu Feng'),
# (11213, 'CS6888001', 'Spring', 2023, 'Mary LouSoffa'),
# (11214, 'CS6890001', 'Spring', 2023, 'John AStankovic'),
# (11215, 'CS6890002', 'Spring', 2023, 'Alfred CWeaver'),
# (11216, 'CS6890003', 'Spring', 2023, 'Haifeng Xu'),
# (11217, 'CS6890004', 'Spring', 2023, 'Xiaozhu Lin'),
# (11218, 'CS6890005', 'Spring', 2023, 'David EEvans'),
# (11219, 'CS6890006', 'Spring', 2023, 'Bradford Campbell'),
# (11220, 'CS6993001', 'Spring', 2023, 'NadaBasit'),
# (11221, 'CS6993002', 'Spring', 2023, 'MohammadMahmoody'),
# (11222, 'CS6993003', 'Spring', 2023, 'Hongning Wang'),
# (11223, 'CS6993004', 'Spring', 2023, 'Aidong Zhang'),
# (11224, 'CS6993005', 'Spring', 2023, 'Yonghwi Kwon'),
# (11225, 'CS7501001', 'Spring', 2023, 'Jack WDavidson'),
# (11226, 'CS7993001', 'Spring', 2023, 'Jundong Li'),
# (11227, 'CS7993002', 'Spring', 2023, 'John AStankovic'),
# (11228, 'CS7993003', 'Spring', 2023, 'Yanjun Qi'),
# (11229, 'CS7993004', 'Spring', 2023, 'MohammadMahmoody'),
# (11230, 'CS7993005', 'Spring', 2023, 'Jonathan LeeGoodall'),
# (11231, 'CS7993006', 'Spring', 2023, 'YangfengJi'),
# (11232, 'CS7993007', 'Spring', 2023, 'Samira ManabiKhan'),
# (11233, 'CS7993008', 'Spring', 2023, 'Marty AHumphrey'),
# (11234, 'CS7993009', 'Spring', 2023, 'Haiying Shen'),
# (11235, 'CS7993010', 'Spring', 2023, 'Ahmed Ibrahim'),
# (11236, 'CS7993011', 'Spring', 2023, 'Vicente Ordonez-Roman'),
# (11237, 'CS7993012', 'Spring', 2023, 'Andrew SGrimshaw'),
# (11238, 'CS7993013', 'Spring', 2023, 'Lu Feng'),
# (11239, 'CS7993014', 'Spring', 2023, 'Madhur Behl'),
# (11240, 'CS7993015', 'Spring', 2023, 'Upsorn Praphamontripong'),
# (11241, 'CS7993016', 'Spring', 2023, 'Yuan Tian'),
# (11242, 'CS7993017', 'Spring', 2023, 'Ashish Venkat'),
# (11243, 'CS7993018', 'Spring', 2023, 'Homa Alemzadeh'),
# (11244, 'CS7993019', 'Spring', 2023, 'Nicola Bezzo'),
# (11245, 'CS7993020', 'Spring', 2023, 'Kristen MNaegle'),
# (11246, 'CS7993021', 'Spring', 2023, 'Denis Nekipelov'),
# (11247, 'CS7993022', 'Spring', 2023, 'Seongkook Heo'),
# (11248, 'CS7993023', 'Spring', 2023, 'KevinSkadron'),
# (11249, 'CS7993024', 'Spring', 2023, 'Haifeng Xu'),
# (11250, 'CS7993025', 'Spring', 2023, 'Michael JAlbert'),
# (11251, 'CS7993026', 'Spring', 2023, 'David J.Wu'),
# (11252, 'CS7993027', 'Spring', 2023, 'Aidong Zhang'),
# (11253, 'CS7993028', 'Spring', 2023, 'Anil Kumar SrinivasaVullikanti'),
# (11254, 'CS7993029', 'Spring', 2023, 'Bradford Campbell'),
# (11255, 'CS7993030', 'Spring', 2023, 'Madhav VMarathe'),
# (11256, 'CS7993031', 'Spring', 2023, 'Xiaozhu Lin'),
# (11257, 'CS7993032', 'Spring', 2023, 'Afsaneh Doryab'),
# (11258, 'CS7993033', 'Spring', 2023, 'Tianhao Wang'),
# (11259, 'CS7995001', 'Spring', 2023, 'Sebastian Elbaum'),
# (11260, 'CS7995002', 'Spring', 2023, 'Nhat HNguyen'),
# (11261, 'CS7995003', 'Spring', 2023, 'NadaBasit'),
# (11262, 'CS7995004', 'Spring', 2023, 'Madhur Behl'),
# (11263, 'CS7995005', 'Spring', 2023, 'MohammadMahmoody'),
# (11264, 'CS7995006', 'Spring', 2023, 'Mary LouSoffa'),
# (11265, 'CS7995007', 'Spring', 2023, 'YangfengJi'),
# (11266, 'CS7995008', 'Spring', 2023, 'Vicente Ordonez-Roman'),
# (11267, 'CS7995009', 'Spring', 2023, 'Yuan Tian'),
# (11268, 'CS7995010', 'Spring', 2023, 'Homa Alemzadeh'),
# (11269, 'CS7995011', 'Spring', 2023, 'Nicola Bezzo'),
# (11270, 'CS7995012', 'Spring', 2023, 'Haifeng Xu'),
# (11271, 'CS7995013', 'Spring', 2023, 'Jonathan LeeGoodall'),
# (11272, 'CS7995014', 'Spring', 2023, 'Kristen MNaegle'),
# (11273, 'CS7995015', 'Spring', 2023, 'Denis Nekipelov'),
# (11274, 'CS7995016', 'Spring', 2023, 'Madhav VMarathe'),
# (11275, 'CS7995017', 'Spring', 2023, 'Seongkook Heo'),
# (11276, 'CS7995018', 'Spring', 2023, 'KevinSkadron'),
# (11277, 'CS7995019', 'Spring', 2023, 'Ashish Venkat'),
# (11278, 'CS8501002', 'Spring', 2023, 'Yuan Tian'),
# (11279, 'CS8501003', 'Spring', 2023, 'Matthew BDwyer'),
# (11280, 'CS8501004', 'Spring', 2023, 'Sebastian Elbaum'),
# (11281, 'CS8897001', 'Spring', 2023, 'Jack WDavidson'),
# (11282, 'CS8897002', 'Spring', 2023, 'David EEvans'),
# (11283, 'CS8897003', 'Spring', 2023, 'MohammadMahmoody'),
# (11284, 'CS8897004', 'Spring', 2023, 'Connelly SBarnes'),
# (11285, 'CS8897005', 'Spring', 2023, 'Marty AHumphrey'),
# (11286, 'CS8897006', 'Spring', 2023, 'KevinSkadron'),
# (11287, 'CS8897007', 'Spring', 2023, 'Mary LouSoffa'),
# (11288, 'CS8897008', 'Spring', 2023, 'John AStankovic'),
# (11289, 'CS8897009', 'Spring', 2023, 'Madhur Behl'),
# (11290, 'CS8897010', 'Spring', 2023, 'Thomas BHorton'),
# (11291, 'CS8897011', 'Spring', 2023, 'James PCohoon'),
# (11292, 'CS8897012', 'Spring', 2023, 'Mark SSherriff'),
# (11293, 'CS8897013', 'Spring', 2023, 'Aaron SBloomfield'),
# (11294, 'CS8897014', 'Spring', 2023, 'GabrielRobins'),
# (11295, 'CS8897015', 'Spring', 2023, 'Yanjun Qi'),
# (11296, 'CS8897016', 'Spring', 2023, 'Worthy NMartin'),
# (11297, 'CS8897017', 'Spring', 2023, 'Bradford Campbell'),
# (11298, 'CS8897018', 'Spring', 2023, 'David LinvilleEdwards'),
# (11299, 'CS8897019', 'Spring', 2023, 'Cameron DeanWhitehouse'),
# (11300, 'CS8897020', 'Spring', 2023, 'NadaBasit'),
# (11301, 'CS8897021', 'Spring', 2023, 'Mary LaverneSmith'),
# (11302, 'CS8897022', 'Spring', 2023, 'Mark RichardFloryan'),
# (11303, 'CS8897023', 'Spring', 2023, 'Luther A.Tychonievich'),
# (11304, 'CS8897024', 'Spring', 2023, 'Hongning Wang'),
# (11305, 'CS8897025', 'Spring', 2023, 'Baishakhi Ray'),
# (11306, 'CS8897026', 'Spring', 2023, 'Samira ManabiKhan'),
# (11307, 'CS8897027', 'Spring', 2023, 'Ahmed Ibrahim'),
# (11308, 'CS8897028', 'Spring', 2023, 'Charles Reiss'),
# (11309, 'CS8897029', 'Spring', 2023, 'Upsorn Praphamontripong'),
# (11310, 'CS8897030', 'Spring', 2023, 'Kong-Cheng Wong'),
# (11311, 'CS8897031', 'Spring', 2023, 'DimitriosDiochnos'),
# (11312, 'CS8897032', 'Spring', 2023, 'Abdeltawab Hendawi'),
# (11313, 'CS8897033', 'Spring', 2023, 'Kai-Wei Chang'),
# (11314, 'CS8897034', 'Spring', 2023, 'Vicente Ordonez-Roman'),
# (11315, 'CS8897035', 'Spring', 2023, 'Lu Feng'),
# (11316, 'CS8897036', 'Spring', 2023, 'Nathan JamesBrunelle'),
# (11317, 'CS8897037', 'Spring', 2023, 'Quanquan Gu'),
# (11318, 'CS8897038', 'Spring', 2023, 'Yuan Tian'),
# (11319, 'CS8897039', 'Spring', 2023, 'Aidong Zhang'),
# (11320, 'CS8897040', 'Spring', 2023, 'David J.Wu'),
# (11321, 'CS8897041', 'Spring', 2023, 'Nhat HNguyen'),
# (11322, 'CS8897042', 'Spring', 2023, 'Alfred CWeaver'),
# (11323, 'CS8897043', 'Spring', 2023, 'Yonghwi Kwon'),
# (11324, 'CS8897044', 'Spring', 2023, 'John RobertHott'),
# (11325, 'CS8897045', 'Spring', 2023, 'Michael RFreenor'),
# (11326, 'CS8897046', 'Spring', 2023, 'Ronald DWilliams'),
# (11327, 'CS8897047', 'Spring', 2023, 'Ashish Venkat'),
# (11328, 'CS8897048', 'Spring', 2023, 'Seongkook Heo'),
# (11329, 'CS8897049', 'Spring', 2023, 'Xiaozhu Lin'),
# (11330, 'CS8897050', 'Spring', 2023, 'Yixin  Sun'),
# (11331, 'CS8897051', 'Spring', 2023, 'YangfengJi'),
# (11332, 'CS8999001', 'Spring', 2023, 'Cameron DeanWhitehouse'),
# (11333, 'CS8999002', 'Spring', 2023, 'James PCohoon'),
# (11334, 'CS8999003', 'Spring', 2023, 'Jack WDavidson'),
# (11335, 'CS8999004', 'Spring', 2023, 'David EEvans'),
# (11336, 'CS8999005', 'Spring', 2023, 'James CFrench'),
# (11337, 'CS8999006', 'Spring', 2023, 'Andrew SGrimshaw'),
# (11338, 'CS8999007', 'Spring', 2023, 'SudhanvaGurumurthi'),
# (11339, 'CS8999008', 'Spring', 2023, 'Kai-Wei Chang'),
# (11340, 'CS8999009', 'Spring', 2023, 'Thomas BHorton'),
# (11341, 'CS8999010', 'Spring', 2023, 'Marty AHumphrey'),
# (11342, 'CS8999011', 'Spring', 2023, 'Vicente Ordonez-Roman'),
# (11343, 'CS8999012', 'Spring', 2023, 'Madhur Behl'),
# (11344, 'CS8999013', 'Spring', 2023, 'Samira ManabiKhan'),
# (11345, 'CS8999014', 'Spring', 2023, 'Worthy NMartin'),
# (11346, 'CS8999015', 'Spring', 2023, 'MohammadMahmoody'),
# (11347, 'CS8999016', 'Spring', 2023, 'GabrielRobins'),
# (11348, 'CS8999017', 'Spring', 2023, 'AbhiShelat'),
# (11349, 'CS8999018', 'Spring', 2023, 'KevinSkadron'),
# (11350, 'CS8999019', 'Spring', 2023, 'Mary LouSoffa'),
# (11351, 'CS8999020', 'Spring', 2023, 'Connelly SBarnes'),
# (11352, 'CS8999021', 'Spring', 2023, 'John AStankovic'),
# (11353, 'CS8999022', 'Spring', 2023, 'Kevin JSullivan'),
# (11354, 'CS8999023', 'Spring', 2023, 'Alfred CWeaver'),
# (11355, 'CS8999024', 'Spring', 2023, 'Bradford Campbell'),
# (11356, 'CS8999025', 'Spring', 2023, 'Yanjun Qi'),
# (11357, 'CS8999026', 'Spring', 2023, 'Hongning Wang'),
# (11358, 'CS8999027', 'Spring', 2023, 'Baishakhi Ray'),
# (11359, 'CS8999028', 'Spring', 2023, 'Lu Feng'),
# (11360, 'CS8999029', 'Spring', 2023, 'Nathan JamesBrunelle'),
# (11361, 'CS8999030', 'Spring', 2023, 'Quanquan Gu'),
# (11362, 'CS8999031', 'Spring', 2023, 'Yuan Tian'),
# (11363, 'CS8999032', 'Spring', 2023, 'Homa Alemzadeh'),
# (11364, 'CS8999033', 'Spring', 2023, 'Farzad FHassanzadeh'),
# (11365, 'CS8999034', 'Spring', 2023, 'Ahmed Ibrahim'),
# (11366, 'CS8999035', 'Spring', 2023, 'Kristen MNaegle'),
# (11367, 'CS8999036', 'Spring', 2023, 'Haiying Shen'),
# (11368, 'CS8999037', 'Spring', 2023, 'Jonathan LeeGoodall'),
# (11369, 'CS8999038', 'Spring', 2023, 'Denis Nekipelov'),
# (11370, 'CS8999039', 'Spring', 2023, 'Preston ThomasFletcher IV'),
# (11371, 'CS8999040', 'Spring', 2023, 'Kristen MNaegle'),
# (11372, 'CS8999041', 'Spring', 2023, 'Anil Kumar SrinivasaVullikanti'),
# (11373, 'CS8999042', 'Spring', 2023, 'Madhav VMarathe'),
# (11374, 'CS8999043', 'Spring', 2023, 'Yonghwi Kwon'),
# (11375, 'CS8999044', 'Spring', 2023, 'Aidong Zhang'),
# (11376, 'CS8999045', 'Spring', 2023, 'David J.Wu'),
# (11377, 'CS8999046', 'Spring', 2023, 'Sebastian Elbaum'),
# (11378, 'CS8999047', 'Spring', 2023, 'YangfengJi'),
# (11379, 'CS8999048', 'Spring', 2023, 'Ashish Venkat'),
# (11380, 'CS8999049', 'Spring', 2023, 'Nicola Bezzo'),
# (11381, 'CS8999050', 'Spring', 2023, 'Seongkook Heo'),
# (11382, 'CS8999051', 'Spring', 2023, 'Matthew BDwyer'),
# (11383, 'CS8999052', 'Spring', 2023, 'Jundong Li'),
# (11384, 'CS8999053', 'Spring', 2023, 'Haifeng Xu'),
# (11385, 'CS8999054', 'Spring', 2023, 'Xiaozhu Lin'),
# (11386, 'CS8999055', 'Spring', 2023, 'Judy Fox'),
# (11387, 'CS8999056', 'Spring', 2023, 'Afsaneh Doryab'),
# (11388, 'CS8999057', 'Spring', 2023, 'Yixin  Sun'),
# (11389, 'CS8999058', 'Spring', 2023, 'Geoffrey C.Fox'),
# (11390, 'CS8999059', 'Spring', 2023, 'Nhat HNguyen'),
# (11391, 'CS8999060', 'Spring', 2023, 'Miaomiao Zhang'),
# (11392, 'CS9897001', 'Spring', 2023, 'James PCohoon'),
# (11393, 'CS9897002', 'Spring', 2023, 'Aaron SBloomfield'),
# (11394, 'CS9897003', 'Spring', 2023, 'Mary LaverneSmith'),
# (11395, 'CS9897004', 'Spring', 2023, 'Luther A.Tychonievich'),
# (11396, 'CS9897005', 'Spring', 2023, 'Jack WDavidson'),
# (11397, 'CS9897006', 'Spring', 2023, 'David EEvans'),
# (11398, 'CS9897007', 'Spring', 2023, 'James CFrench'),
# (11399, 'CS9897008', 'Spring', 2023, 'Andrew SGrimshaw'),
# (11400, 'CS9897009', 'Spring', 2023, 'Worthy NMartin'),
# (11401, 'CS9897010', 'Spring', 2023, 'David LinvilleEdwards'),
# (11402, 'CS9897011', 'Spring', 2023, 'Mark RichardFloryan'),
# (11403, 'CS9897012', 'Spring', 2023, 'Thomas BHorton'),
# (11404, 'CS9897013', 'Spring', 2023, 'Marty AHumphrey'),
# (11405, 'CS9897014', 'Spring', 2023, 'MohammadMahmoody'),
# (11406, 'CS9897015', 'Spring', 2023, 'Madhur Behl'),
# (11407, 'CS9897016', 'Spring', 2023, 'NadaBasit'),
# (11408, 'CS9897017', 'Spring', 2023, 'Connelly SBarnes'),
# (11409, 'CS9897018', 'Spring', 2023, 'AbhiShelat'),
# (11410, 'CS9897019', 'Spring', 2023, 'Mark SSherriff'),
# (11411, 'CS9897020', 'Spring', 2023, 'KevinSkadron'),
# (11412, 'CS9897021', 'Spring', 2023, 'Mary LouSoffa'),
# (11413, 'CS9897022', 'Spring', 2023, 'Yanjun Qi'),
# (11414, 'CS9897023', 'Spring', 2023, 'John AStankovic'),
# (11415, 'CS9897024', 'Spring', 2023, 'Kevin JSullivan'),
# (11416, 'CS9897025', 'Spring', 2023, 'Alfred CWeaver'),
# (11417, 'CS9897026', 'Spring', 2023, 'Bradford Campbell'),
# (11418, 'CS9897027', 'Spring', 2023, 'GabrielRobins'),
# (11419, 'CS9897028', 'Spring', 2023, 'Cameron DeanWhitehouse'),
# (11420, 'CS9897029', 'Spring', 2023, 'Baishakhi Ray'),
# (11421, 'CS9897030', 'Spring', 2023, 'Samira ManabiKhan'),
# (11422, 'CS9897031', 'Spring', 2023, 'Kong-Cheng Wong'),
# (11423, 'CS9897032', 'Spring', 2023, 'Ahmed Ibrahim'),
# (11424, 'CS9897033', 'Spring', 2023, 'Charles Reiss'),
# (11425, 'CS9897034', 'Spring', 2023, 'Upsorn Praphamontripong'),
# (11426, 'CS9897035', 'Spring', 2023, 'David LinvilleEdwards'),
# (11427, 'CS9897036', 'Spring', 2023, 'Mary LaverneSmith'),
# (11428, 'CS9897037', 'Spring', 2023, 'Kong-Cheng Wong'),
# (11429, 'CS9897038', 'Spring', 2023, 'DimitriosDiochnos'),
# (11430, 'CS9897039', 'Spring', 2023, 'Abdeltawab Hendawi'),
# (11431, 'CS9897040', 'Spring', 2023, 'Kai-Wei Chang'),
# (11432, 'CS9897041', 'Spring', 2023, 'Vicente Ordonez-Roman'),
# (11433, 'CS9897042', 'Spring', 2023, 'Katherine AHolcomb'),
# (11434, 'CS9897043', 'Spring', 2023, 'Thomas EdwinHall'),
# (11435, 'CS9897044', 'Spring', 2023, 'Lu Feng'),
# (11436, 'CS9897045', 'Spring', 2023, 'Nathan JamesBrunelle'),
# (11437, 'CS9897046', 'Spring', 2023, 'Quanquan Gu'),
# (11438, 'CS9897047', 'Spring', 2023, 'Yuan Tian'),
# (11439, 'CS9897048', 'Spring', 2023, 'Aidong Zhang'),
# (11440, 'CS9897049', 'Spring', 2023, 'David J.Wu'),
# (11441, 'CS9897050', 'Spring', 2023, 'John RobertHott'),
# (11442, 'CS9897051', 'Spring', 2023, 'Daniel GeorgeGraham'),
# (11443, 'CS9897052', 'Spring', 2023, 'Ronald DWilliams'),
# (11444, 'CS9897053', 'Spring', 2023, 'Ashish Venkat'),
# (11445, 'CS9897054', 'Spring', 2023, 'YangfengJi'),
# (11446, 'CS9897055', 'Spring', 2023, 'Haifeng Xu'),
# (11447, 'CS9897056', 'Spring', 2023, 'Xiaozhu Lin'),
# (11448, 'CS9897057', 'Spring', 2023, 'Tianhao Wang'),
# (11449, 'CS9897058', 'Spring', 2023, 'Preston ThomasFletcher IV'),
# (11450, 'CS9999001', 'Spring', 2023, 'Marty AHumphrey'),
# (11451, 'CS9999002', 'Spring', 2023, 'Cameron DeanWhitehouse'),
# (11452, 'CS9999003', 'Spring', 2023, 'Alfred CWeaver'),
# (11453, 'CS9999004', 'Spring', 2023, 'John AStankovic'),
# (11454, 'CS9999005', 'Spring', 2023, 'Kai-Wei Chang'),
# (11455, 'CS9999006', 'Spring', 2023, 'James PCohoon'),
# (11456, 'CS9999007', 'Spring', 2023, 'Jack WDavidson'),
# (11457, 'CS9999008', 'Spring', 2023, 'David EEvans'),
# (11458, 'CS9999009', 'Spring', 2023, 'James CFrench'),
# (11459, 'CS9999010', 'Spring', 2023, 'Andrew SGrimshaw'),
# (11460, 'CS9999011', 'Spring', 2023, 'SudhanvaGurumurthi'),
# (11461, 'CS9999012', 'Spring', 2023, 'MohammadMahmoody'),
# (11462, 'CS9999013', 'Spring', 2023, 'Connelly SBarnes'),
# (11463, 'CS9999014', 'Spring', 2023, 'Madhur Behl'),
# (11464, 'CS9999015', 'Spring', 2023, 'Worthy NMartin'),
# (11465, 'CS9999016', 'Spring', 2023, 'Yanjun Qi'),
# (11466, 'CS9999017', 'Spring', 2023, 'GabrielRobins'),
# (11467, 'CS9999018', 'Spring', 2023, 'AbhiShelat'),
# (11468, 'CS9999019', 'Spring', 2023, 'KevinSkadron'),
# (11469, 'CS9999020', 'Spring', 2023, 'Mary LouSoffa'),
# (11470, 'CS9999021', 'Spring', 2023, 'Vicente Ordonez-Roman'),
# (11471, 'CS9999022', 'Spring', 2023, 'Kevin JSullivan'),
# (11472, 'CS9999023', 'Spring', 2023, 'Westley RWeimer'),
# (11473, 'CS9999024', 'Spring', 2023, 'Baishakhi Ray'),
# (11474, 'CS9999025', 'Spring', 2023, 'Samira ManabiKhan'),
# (11475, 'CS9999026', 'Spring', 2023, 'Hongning Wang'),
# (11476, 'CS9999027', 'Spring', 2023, 'Haiying Shen'),
# (11477, 'CS9999028', 'Spring', 2023, 'Lu Feng'),
# (11478, 'CS9999029', 'Spring', 2023, 'Bradford Campbell'),
# (11479, 'CS9999030', 'Spring', 2023, 'Nathan JamesBrunelle'),
# (11480, 'CS9999031', 'Spring', 2023, 'Quanquan Gu'),
# (11481, 'CS9999032', 'Spring', 2023, 'Yuan Tian'),
# (11482, 'CS9999033', 'Spring', 2023, 'Farzad FHassanzadeh'),
# (11483, 'CS9999034', 'Spring', 2023, 'Anil Kumar SrinivasaVullikanti'),
# (11484, 'CS9999035', 'Spring', 2023, 'Madhav VMarathe'),
# (11485, 'CS9999036', 'Spring', 2023, 'Yonghwi Kwon'),
# (11486, 'CS9999037', 'Spring', 2023, 'Aidong Zhang'),
# (11487, 'CS9999038', 'Spring', 2023, 'David J.Wu'),
# (11488, 'CS9999039', 'Spring', 2023, 'Matthew BDwyer'),
# (11489, 'CS9999040', 'Spring', 2023, 'Sebastian Elbaum'),
# (11490, 'CS9999041', 'Spring', 2023, 'Ashish Venkat'),
# (11491, 'CS9999042', 'Spring', 2023, 'Jundong Li'),
# (11492, 'CS9999043', 'Spring', 2023, 'YangfengJi'),
# (11493, 'CS9999044', 'Spring', 2023, 'Haifeng Xu'),
# (11494, 'CS9999045', 'Spring', 2023, 'Xiaozhu Lin'),
# (11495, 'CS9999046', 'Spring', 2023, 'Seongkook Heo'),
# (11496, 'CS9999047', 'Spring', 2023, 'Yixin  Sun'),
